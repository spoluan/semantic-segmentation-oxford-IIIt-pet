# %% [markdown]
# # Semantic Segmentation on Oxford-IIIT Pet
# **Author:** Sevendi Eldrige Rifki Poluan
#
# This notebook builds and evaluates a U-Net style semantic segmentation model with a VGG16 encoder on the Oxford-IIIT Pet dataset. The goal is to predict a class label for each pixel (pet, border, background).

# %%
# !nvidia-smi
# Out:
# Sat May 20 21:41:53 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.116.04   Driver Version: 525.116.04   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:65:00.0 Off |                  N/A |
# |  0%   47C    P8    38W / 390W |  23440MiB / 24576MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# !pip install tensorflow_datasets

# %% [markdown]
# ## 1. Import Required Libraries
# Load TensorFlow, NumPy, Matplotlib, TensorFlow Datasets, and Pandas for data handling, model construction, training, and visualization.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
import pandas as pd

# %% [markdown]
# ## 2. Prepare the Dataset
# Download and load the Oxford-IIIT Pet dataset, split it into training and testing partitions, and inspect sample dimensions before preprocessing.

# %%
tfds.builder('oxford_iiit_pet:3.*.*').download_and_prepare(download_dir="./")

# %%
dataset, info = tfds.load('oxford_iiit_pet:3.*.*', with_info=True)
# Out:
# 2023-05-20 19:25:30.614495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22244 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:65:00.0, compute capability: 8.6

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']

# %%
len(train_dataset), len(test_dataset)
# Out:
# (3680, 3669)

# %%
for x in train_dataset:
    print("Image default size: ", x["image"].numpy().shape)
    print("Image segmentation default size: ", x["segmentation_mask"].numpy().shape)
    break
# Out:
# Image default size:  (500, 500, 3)
# Image segmentation default size:  (500, 500, 1)

# %%
print("Sample data", x)
# Out:
# Sample data {'file_name': <tf.Tensor: shape=(), dtype=string, numpy=b'Sphynx_158.jpg'>, 'image': <tf.Tensor: shape=(500, 500, 3), dtype=uint8, numpy=
# array([[[ 3,  3,  3],
#         [ 5,  3,  4],
#         [ 7,  5,  6],
#         ...,
#         [ 3,  1,  2],
#         [ 3,  1,  2],
#         [ 3,  1,  2]],
#
#        [[ 4,  3,  1],
#         [ 5,  3,  4],
#         [ 5,  3,  4],
#         ...,
#         [ 6,  2,  3],
#         [ 7,  3,  4],
#         [ 8,  4,  5]],
#
#        [[ 4,  3,  1],
#         [ 5,  4,  2],
#         [ 5,  3,  4],
#         ...,
#         [ 7,  3,  2],
#         [ 8,  4,  3],
#         [ 8,  4,  3]],
#
#        ...,
#
#        [[ 6, 10, 11],
#         [ 6,  7,  9],
#         [ 7,  8, 10],
#         ...,
#         [ 3,  4,  6],
#         [ 3,  4,  6],
#         [ 4,  5,  7]],
#
#        [[ 8, 12, 13],
#         [ 7,  8, 10],
#         [ 8,  9, 11],
#         ...,
#         [ 4,  5,  9],
#         [ 4,  5,  7],
#         [ 4,  5,  7]],
#
#        [[ 8, 12, 13],
#         [ 7,  8, 10],
#         [ 8,  9, 11],
#         ...,
#         [ 5,  6, 10],
#         [ 5,  6, 10],
#         [ 5,  6, 10]]], dtype=uint8)>, 'label': <tf.Tensor: shape=(), dtype=int64, numpy=33>, 'segmentation_mask': <tf.Tensor: shape=(500, 500, 1), dtype=uint8, numpy=
# array([[[2],
#         [2],
#         [2],
#         ...,
#         [2],
#         [2],
#         [2]],
#
#        [[2],
#         [2],
#         [2],
#         ...,
#         [2],
#         [2],
#         [2]],
#
#        [[2],
#         [2],
#         [2],
#         ...,
#         [2],
#         [2],
#         [2]],
#
#        ...,
#
#        [[2],
#         [2],
#         [2],
#         ...,
#         [2],
#         [2],
#         [2]],
#
#        [[2],
#         [2],
#         [2],
#         ...,
#         [2],
#         [2],
#         [2]],
#
#        [[2],
#         [2],
#         [2],
#         ...,
#         [2],
#         [2],
#         [2]]], dtype=uint8)>, 'species': <tf.Tensor: shape=(), dtype=int64, numpy=0>}

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.imshow(x["image"].numpy())
plt.subplot(1, 2, 2)
plt.imshow(x["segmentation_mask"].numpy())

# %%
BATCH_SIZE = 32
IMG_SIZE = [256, 256]

def func(data):
    image = data["image"]
    target = data["segmentation_mask"]
    
    # resize the image
    image = tf.image.resize(image, IMG_SIZE)
    target = tf.image.resize(target, IMG_SIZE)
    
    # normalize the image
    image = tf.cast(image, tf.float32) * (1. / 255.)
    target = target - 1
    
    return image, target

train_ds = train_dataset.map(func).shuffle(buffer_size=1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE).cache()
test_ds = test_dataset.map(func).shuffle(buffer_size=1000).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## 3. Build the Segmentation Model
# Define helper upsampling blocks and construct a U-Net style architecture that uses VGG16 as the encoder backbone and a decoder for dense pixel prediction.

# %%
def upsample(input_to_upsample, link_to):  
    
    # Upsample the input_to_upsample using Conv2DTranspose
    up = tf.keras.layers.Conv2DTranspose(
                 link_to.shape[-2],  # sample: (None, 16, "16", 512) = 16
                 kernel_size = 3,
                 strides=(2, 2), # link_to.shape[-2] * 2
                 padding='same')(input_to_upsample) 
    
    # Concatenate the upsampled feature map with the link_to feature map
    merge = tf.keras.layers.concatenate([up, link_to], axis=3) 
    
    # Apply convolution on the merged feature map
    conv = tf.keras.layers.Conv2D(input_to_upsample.shape[-1], # sample: (None, 8, 8, "512") = 512
                 kernel_size = 3,  
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(merge)
    
    return merge

# %%
def unet(): 
    
    # I'll use VGG16 to build our base model
    base_model = tf.keras.applications.VGG16(input_shape=IMG_SIZE + [3], include_top=False)
    
    # Selects and stores the layers from the base model that have "conv1" in their names, in reverse order. 
    # I am just selecting a specific layer that will be combined (concatenated) with the final output from the VGG16 model for constructing our U-Net model.
    link_tos = [x for x in base_model.layers if "conv1" in x.name][::-1]
    
    # Set the initial upsampled value as the output of the base model
    upsampled = base_model.output
    
    # Iterate over the selected layers and perform upsampling
    for count, link in enumerate(link_tos): 
        upsampled = upsample(upsampled, link.output)
    
    # Apply a final convolutional layer to generate the model's outputs
    outputs = tf.keras.layers.Conv2D(3,  
                     kernel_size = 3,  
                     activation='softmax',
                     padding='same',
                     kernel_initializer=tf.keras.initializers.HeNormal())(upsampled)
    
    # Create the U-Net model with the base model's input as the input and the outputs from the final convolutional layer
    model = tf.keras.Model(base_model.inputs[0], outputs)
    model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=tf.keras.optimizers.Adam(),
        metrics=["accuracy"]
    )
    return model

# %%
unet_model = unet()

# %%
tf.keras.utils.plot_model(unet_model, show_dtype=True, show_shapes=True, show_layer_activations=True, show_trainable=True)

# %% [markdown]
# ## 4. Configure Callbacks
# Create training callbacks to improve training behavior and reduce overfitting risk. Early stopping is used to monitor validation accuracy.

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=10)

# %% [markdown]
# ## 5. Train the Model
# Fit the segmentation model on the prepared training dataset and validate it on test data. Model weights are saved after training.

# %%
EPOCHS = 500
history = unet_model.fit(train_ds, epochs=EPOCHS, validation_data=test_ds, validation_steps=len(test_ds) * .2, callbacks=[early_stopping])
# Out:
# Epoch 1/500
# 2023-05-20 19:40:26.866450: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int64 and shape [4]
# 	 [[{{node Placeholder/_4}}]]
# 2023-05-20 19:40:26.867384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_1' with dtype string and shape [4]
# 	 [[{{node Placeholder/_1}}]]
# Corrupt JPEG data: 240 extraneous bytes before marker 0xd9
# Corrupt JPEG data: premature end of data segment
# 115/115 [==============================] - ETA: 0s - loss: 0.9011 - accuracy: 0.6666
# 2023-05-20 19:41:07.786814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [4]
# 	 [[{{node Placeholder/_0}}]]
# 2023-05-20 19:41:07.787179: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int64 and shape [4]
# 	 [[{{node Placeholder/_4}}]]
# 115/115 [==============================] - 44s 335ms/step - loss: 0.9011 - accuracy: 0.6666 - val_loss: 0.6406 - val_accuracy: 0.7346
# Epoch 2/500
# 115/115 [==============================] - 38s 333ms/step - loss: 0.5810 - accuracy: 0.7574 - val_loss: 0.5345 - val_accuracy: 0.7754
# Epoch 3/500
# 115/115 [==============================] - 38s 333ms/step - loss: 0.4989 - accuracy: 0.7925 - val_loss: 0.4701 - val_accuracy: 0.8059
# Epoch 4/500
# 115/115 [==============================] - 38s 334ms/step - loss: 0.4299 - accuracy: 0.8227 - val_loss: 0.3797 - val_accuracy: 0.8471
# Epoch 5/500
# 115/115 [==============================] - 39s 338ms/step - loss: 0.3805 - accuracy: 0.8443 - val_loss: 0.3845 - val_accuracy: 0.8442
# Epoch 6/500
# 115/115 [==============================] - 38s 335ms/step - loss: 0.3414 - accuracy: 0.8603 - val_loss: 0.3313 - val_accuracy: 0.8659
# Epoch 7/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.3099 - accuracy: 0.8723 - val_loss: 0.3430 - val_accuracy: 0.8645
# Epoch 8/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.2975 - accuracy: 0.8773 - val_loss: 0.3429 - val_accuracy: 0.8677
# Epoch 9/500
# 115/115 [==============================] - 39s 336ms/step - loss: 0.2875 - accuracy: 0.8815 - val_loss: 0.2919 - val_accuracy: 0.8819
# Epoch 10/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.2607 - accuracy: 0.8917 - val_loss: 0.2849 - val_accuracy: 0.8869
# Epoch 11/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.2551 - accuracy: 0.8938 - val_loss: 0.3149 - val_accuracy: 0.8785
# Epoch 12/500
# 115/115 [==============================] - 38s 335ms/step - loss: 0.2382 - accuracy: 0.9001 - val_loss: 0.3015 - val_accuracy: 0.8859
# Epoch 13/500
# 115/115 [==============================] - 39s 337ms/step - loss: 0.2359 - accuracy: 0.9008 - val_loss: 0.2847 - val_accuracy: 0.8887
# Epoch 14/500
# 115/115 [==============================] - 38s 335ms/step - loss: 0.2239 - accuracy: 0.9056 - val_loss: 0.2857 - val_accuracy: 0.8892
# Epoch 15/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.2237 - accuracy: 0.9057 - val_loss: 0.2881 - val_accuracy: 0.8917
# Epoch 16/500
# 115/115 [==============================] - 39s 337ms/step - loss: 0.2106 - accuracy: 0.9104 - val_loss: 0.3121 - val_accuracy: 0.8836
# Epoch 17/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.2022 - accuracy: 0.9137 - val_loss: 0.2977 - val_accuracy: 0.8905
# Epoch 18/500
# 115/115 [==============================] - 39s 336ms/step - loss: 0.2007 - accuracy: 0.9142 - val_loss: 0.3178 - val_accuracy: 0.8820
# Epoch 19/500
# 115/115 [==============================] - 38s 335ms/step - loss: 0.2079 - accuracy: 0.9116 - val_loss: 0.3360 - val_accuracy: 0.8696
# Epoch 20/500
# 115/115 [==============================] - 38s 335ms/step - loss: 0.2009 - accuracy: 0.9141 - val_loss: 0.2825 - val_accuracy: 0.8915
# Epoch 21/500
# 115/115 [==============================] - 39s 336ms/step - loss: 0.1762 - accuracy: 0.9233 - val_loss: 0.2962 - val_accuracy: 0.8928
# Epoch 22/500
# 115/115 [==============================] - 38s 335ms/step - loss: 0.1646 - accuracy: 0.9274 - val_loss: 0.3005 - val_accuracy: 0.8941
# Epoch 23/500
# 115/115 [==============================] - 39s 338ms/step - loss: 0.1548 - accuracy: 0.9311 - val_loss: 0.3246 - val_accuracy: 0.8903
# Epoch 24/500
# 115/115 [==============================] - 38s 335ms/step - loss: 0.1499 - accuracy: 0.9329 - val_loss: 0.3319 - val_accuracy: 0.8894
# Epoch 25/500
# 115/115 [==============================] - 39s 337ms/step - loss: 0.1488 - accuracy: 0.9334 - val_loss: 0.3212 - val_accuracy: 0.8884
# Epoch 26/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.1517 - accuracy: 0.9324 - val_loss: 0.3041 - val_accuracy: 0.8900
# Epoch 27/500
# 115/115 [==============================] - 39s 337ms/step - loss: 0.1477 - accuracy: 0.9339 - val_loss: 0.2850 - val_accuracy: 0.8955
# Epoch 28/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.1467 - accuracy: 0.9346 - val_loss: 0.3294 - val_accuracy: 0.8878
# Epoch 29/500
# 115/115 [==============================] - 39s 336ms/step - loss: 0.1468 - accuracy: 0.9344 - val_loss: 0.3085 - val_accuracy: 0.8959
# Epoch 30/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.1796 - accuracy: 0.9224 - val_loss: 0.3370 - val_accuracy: 0.8822
# Epoch 31/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.1567 - accuracy: 0.9306 - val_loss: 0.3154 - val_accuracy: 0.8941
# Epoch 32/500
# 115/115 [==============================] - 38s 335ms/step - loss: 0.1417 - accuracy: 0.9364 - val_loss: 0.3514 - val_accuracy: 0.8900
# Epoch 33/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.1392 - accuracy: 0.9375 - val_loss: 0.3472 - val_accuracy: 0.8857
# Epoch 34/500
# 115/115 [==============================] - 39s 335ms/step - loss: 0.1362 - accuracy: 0.9386 - val_loss: 0.3023 - val_accuracy: 0.8943
# Epoch 35/500
# 115/115 [==============================] - 39s 336ms/step - loss: 0.1370 - accuracy: 0.9383 - val_loss: 0.3261 - val_accuracy: 0.8907
# Epoch 36/500
# 115/115 [==============================] - 39s 336ms/step - loss: 0.1303 - accuracy: 0.9409 - val_loss: 0.3878 - val_accuracy: 0.8913
# Epoch 37/500
# 115/115 [==============================] - 38s 334ms/step - loss: 0.1258 - accuracy: 0.9427 - val_loss: 0.3988 - val_accuracy: 0.8832
# Epoch 38/500
# 115/115 [==============================] - 38s 335ms/step - loss: 0.1273 - accuracy: 0.9424 - val_loss: 0.3561 - val_accuracy: 0.8908
# Epoch 39/500
# 115/115 [==============================] - 39s 336ms/step - loss: 0.1267 - accuracy: 0.9426 - val_loss: 0.3889 - val_accuracy: 0.8825

# %%
unet_model.save_weights("Saved model/model.weights.h5")

# %% [markdown]
# ## 6. Evaluate Training Performance
# Visualize training history (loss and accuracy curves) and compute quantitative performance on the test split.

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
test_performance = unet_model.evaluate(test_ds)
print("Testing accurracy: ", test_performance[1])
# Out:
# 115/115 [==============================] - 14s 118ms/step - loss: 0.4023 - accuracy: 0.8807
# Testing accurracy:  0.8807401061058044

# %% [markdown]
# ## 7. Visualize Sample Predictions
# Display qualitative prediction examples by comparing input images, predicted masks, and ground-truth target masks.

# %%
prediction_results.shape
# Out:
# (32, 256, 256, 3)

# %%
# Create subplots with 32 rows and 3 columns, adjusting the figure size
fig, axes = plt.subplots(32, 3, figsize=(10, 70))

# Iterate over the test dataset
for index, batch_test in enumerate(test_ds):
    
    #  Extract inputs and targets from the batch
    inputs, targets = batch_test
    
    # Predict using the U-Net model
    prediction_results = unet_model.predict(inputs)
    
    # Iterate over inputs, predictions, and targets
    for i, (j, x, y) in enumerate(zip(inputs, prediction_results, targets)):  
        
        # Convert the prediction to class labels
        x = x.argmax(axis=-1)
        
        # Set titles for each subplot
        axes[i, 0].set_title("Input")
        axes[i, 1].set_title("Prediction")
        axes[i, 2].set_title("Target")
        
        # Display images in each subplot
        axes[i, 0].imshow(j) 
        axes[i, 1].imshow(x)
        axes[i, 2].imshow(y)
    
    # Adjust the spacing between subplots
    plt.tight_layout()
    
    # Display the figure with subplots
    plt.show()
    
    # Break the loop after the first iteration
    break
# Out:
# 1/1 [==============================] - 0s 29ms/step
